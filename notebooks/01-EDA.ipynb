# %%
# imports
import pandas as pd
import numpy as np
from textblob import TextBlob


# load
news = pd.read_csv('data/raw/news.csv', parse_dates=['date'])
news['headline_len'] = news['headline'].str.len()
# basic stats
news.describe()


# publisher counts
news['publisher'].value_counts().head(20)


# save
news.to_csv('data/processed/news_processed.csv', index=False)
